# %%
from new_gps_spark_logic import GpsPingCluster

# %%
gpc = GpsPingCluster()

# %%
gpc.init_spark(6)
# Out:
# ('setting master to: ', 'spark://172.25.0.09:7077')

# %%
gpc.load_daily_feed_reduced('local','2020-07-29','2020-08-01')
# Out:
# ['/opt/spark/sample_data/daily-feed-reduced/US/20200729*/*.csv.gz', '/opt/spark/sample_data/daily-feed-reduced/US/20200730*/*.csv.gz', '/opt/spark/sample_data/daily-feed-reduced/US/20200731*/*.csv.gz', '/opt/spark/sample_data/daily-feed-reduced/US/20200801*/*.csv.gz']
#
# Running the following date(s) (4 total):
#    07/29/20
#    07/30/20
#    07/31/20
#    08/01/20
#
# 749,248 pings loaded for analysis

# %%
gpc.chain_pings()
# Out:
# _______________________________________________
# CHAINING PINGS
#
#
# Phase            Ping Count    Removed Pings    Percent Reduction  Description
# -------------  ------------  ---------------  -------------------  ---------------------------------------------------------------------------------
# Initial count        749248                0                 0.00  Count of pings prior to analyzing spatial relationships
# Chained count        475127           274121                36.59  Count of pings that have spatially proximate neighbors to consider for clustering

# %%
gpc.anchor_pings()
# Out:
# _______________________________________________
# ANCHORING PINGS
#
#
# 475,127 pings being considered for anchoring
#
# Iteration 1: 49,985 records remaining
# Iteration 2: 23,375 records remaining
# Iteration 3: 13,172 records remaining
# Iteration 4: 8,993 records remaining
# Iteration 5: 6,872 records remaining
# Iteration 6: 4,760 records remaining
# Iteration 7: 3,684 records remaining
# Iteration 8: 2,701 records remaining
# Iteration 9: 2,248 records remaining
# Iteration 10: 1,548 records remaining
# Iteration 11: 1,355 records remaining
# Iteration 12: 976 records remaining
# Iteration 13: 833 records remaining
# Iteration 14: 748 records remaining
# Iteration 15: 603 records remaining
# Iteration 16: 581 records remaining
# Iteration 17: 546 records remaining
# Iteration 18: 534 records remaining
# Iteration 19: 480 records remaining
# Iteration 20: 390 records remaining
# Iteration 21: 301 records remaining
# Iteration 22: 282 records remaining
# ...
